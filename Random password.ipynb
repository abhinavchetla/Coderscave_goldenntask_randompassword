# %%
import random
import string

def generate_password(length, include_special_chars, include_numbers):
    # Define the character set
    password_characters = string.ascii_letters

    if include_special_chars:
        password_characters += string.punctuation

    if include_numbers:
        password_characters += string.digits

    # Generate the password
    password = ''.join(random.choice(password_characters) for i in range(length))

    return password

while True:
    length = int(input("Enter the length of the password: "))
    include_special_chars = input("Include special characters? (yes/no): ").lower() == 'yes'
    include_numbers = input("Include numbers? (yes/no): ").lower() == 'yes'

    if length > 0:
        password = generate_password(length, include_special_chars, include_numbers)
        print("Generated password: ", password)
    else:
        print("Password length must be greater than 0.")

    generate_another = input("Generate another password? (yes/no): ").lower()
    if generate_another != 'yes':
        break
# Out:
# Enter the length of the password: 6
# Include special characters? (yes/no): yes
# Include numbers? (yes/no): yes
# Generated password:  ">@V*g
# Generate another password? (yes/no): no
